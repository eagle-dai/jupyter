# %% [markdown]
# https://www.youtube.com/watch?v=vOppzHpvTiQ&index=1&t=2s&list=PL2-dafEMk2A7YdKv4XfKpfbTH5z6rEEj3
#
# at 4:44

# %%
import pandas as pd
from sklearn import linear_model
import matplotlib.pyplot as plt

#read data
datafram = pd.read_fwf('1-brain_body.csv')
datafram
# Out:
#       Brain    Body
# 0     3.385   44.50
# 1     0.480   15.50
# 2     1.350    8.10
# 3   465.000  423.00
# 4    36.330  119.50
# 5    27.660  115.00
# 6    14.830   98.20
# 7     1.040    5.50
# 8     4.190   58.00
# 9     0.425    6.40
# 10    0.101    4.00
# 11    0.920    5.70
# 12    1.000    6.60
# 13    0.005    0.14
# 14    0.060    1.00
# 15    3.500   10.80
